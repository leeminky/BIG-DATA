# %% [markdown]
# ## 과제: Key-Value RDD를 이용한 황순원의 '소나기'의 단어별 빈도 세기
# + [+]에 해당되는 코드를 완성할 것

# %% [markdown]
# ### 1. Spark 애플리케이션 시작

# %%
# [+] SparkConf, SparkContext 임포트
from pyspark import SparkConf, SparkContext

# %%
# [+] SparkConf, SparkContext 생성
conf = SparkConf().setMaster('local').setAppName('assgn_key_value')
sc = SparkContext(conf=conf)

# %% [markdown]
# ### 2. 황순원의 소나기 원문(.txt) 불러오기

# %%
# 파일 이름과 경로
path = './data/'
filename = 'rainshower.txt'

# %%
# [+] textFile()을 이용하여 원문(.txt)을 읽어 RDD 객체로 생성하기
lines = sc.textFile("./data/"+filename)

# %%
# [+] take()을 이용하여 RDD 객체의 값 100개(= 100 줄) 출력
rdd=sc.parallelize(lines.take(100))
rdd
# Out:
# ParallelCollectionRDD[3] at readRDDFromFile at PythonRDD.scala:274

# %% [markdown]
# ### 3. (단어, 1) 형태의 Key-Value RDD 생성하기

# %%
# [+] flatMap()를 이용하여 각 문장들을 단어 단위로 분리 및 저장
words = rdd.flatMap(lambda x: x.split(" "))

# %%
# [+] words 객체의 값 100개 출력
word_pairs=words.take(100)
word_pairs
# Out:
# ['소년은',
#  '개울가에서',
#  '소녀를',
#  '보자',
#  '곧',
#  '윤',
#  '초시네',
#  '증손녀(曾孫女)딸이라는',
#  '걸',
#  '알',
#  '수',
#  '있었다.',
#  '소녀는',
#  '개울에다',
#  '손을',
#  '잠그고',
#  '물장난을',
#  '하고',
#  '있는',
#  '것이다.',
#  '서울서는',
#  '이런',
#  '개울물을',
#  '보지',
#  '못하기나',
#  '한',
#  '듯이.',
#  '벌써',
#  '며칠째',
#  '소녀는,',
#  '학교에서',
#  '돌아오는',
#  '길에',
#  '물장난이었다.',
#  '그런데,',
#  '어제까지',
#  '개울',
#  '기슭에서',
#  '하더니,',
#  '오늘은',
#  '징검다리',
#  '한가운데',
#  '앉아서',
#  '하고',
#  '있다.',
#  '소년은',
#  '개울둑에',
#  '앉아',
#  '버렸다.',
#  '소녀가',
#  '비키기를',
#  '기다리자는',
#  '것이다.',
#  '요행',
#  '지나가는',
#  '사람이',
#  '있어,',
#  '소녀가',
#  '길을',
#  '비켜',
#  '주었다.',
#  '다음',
#  '날은',
#  '좀',
#  '늦게',
#  '개울가로',
#  '나왔다.',
#  '이',
#  '날은',
#  '소녀가',
#  '징검다리',
#  '한가운데',
#  '앉아',
#  '세수를',
#  '하고',
#  '있었다.',
#  '분홍',
#  '스웨터',
#  '소매를',
#  '걷어올린',
#  '목덜미가',
#  '마냥',
#  '희었다.',
#  '한참',
#  '세수를',
#  '하고',
#  '나더니,',
#  '이번에는',
#  '물',
#  '속을',
#  '빤히',
#  '들여다',
#  '본다.',
#  '얼굴이라도',
#  '비추어',
#  '보는',
#  '것이리라.',
#  '갑자기',
#  '물을',
#  '움켜']

# %%
# [+] map()을 이용하여 (단어, 1) 형태의 Key-Value RDD로 변환
word_pairs = words.map(lambda x: (x, 1))

# %%
# [+] word_pairs 객체의 값 100개 출력
word_counts=word_pairs.take(100)
word_counts
# Out:
# [('소년은', 1),
#  ('개울가에서', 1),
#  ('소녀를', 1),
#  ('보자', 1),
#  ('곧', 1),
#  ('윤', 1),
#  ('초시네', 1),
#  ('증손녀(曾孫女)딸이라는', 1),
#  ('걸', 1),
#  ('알', 1),
#  ('수', 1),
#  ('있었다.', 1),
#  ('소녀는', 1),
#  ('개울에다', 1),
#  ('손을', 1),
#  ('잠그고', 1),
#  ('물장난을', 1),
#  ('하고', 1),
#  ('있는', 1),
#  ('것이다.', 1),
#  ('서울서는', 1),
#  ('이런', 1),
#  ('개울물을', 1),
#  ('보지', 1),
#  ('못하기나', 1),
#  ('한', 1),
#  ('듯이.', 1),
#  ('벌써', 1),
#  ('며칠째', 1),
#  ('소녀는,', 1),
#  ('학교에서', 1),
#  ('돌아오는', 1),
#  ('길에', 1),
#  ('물장난이었다.', 1),
#  ('그런데,', 1),
#  ('어제까지', 1),
#  ('개울', 1),
#  ('기슭에서', 1),
#  ('하더니,', 1),
#  ('오늘은', 1),
#  ('징검다리', 1),
#  ('한가운데', 1),
#  ('앉아서', 1),
#  ('하고', 1),
#  ('있다.', 1),
#  ('소년은', 1),
#  ('개울둑에', 1),
#  ('앉아', 1),
#  ('버렸다.', 1),
#  ('소녀가', 1),
#  ('비키기를', 1),
#  ('기다리자는', 1),
#  ('것이다.', 1),
#  ('요행', 1),
#  ('지나가는', 1),
#  ('사람이', 1),
#  ('있어,', 1),
#  ('소녀가', 1),
#  ('길을', 1),
#  ('비켜', 1),
#  ('주었다.', 1),
#  ('다음', 1),
#  ('날은', 1),
#  ('좀', 1),
#  ('늦게', 1),
#  ('개울가로', 1),
#  ('나왔다.', 1),
#  ('이', 1),
#  ('날은', 1),
#  ('소녀가', 1),
#  ('징검다리', 1),
#  ('한가운데', 1),
#  ('앉아', 1),
#  ('세수를', 1),
#  ('하고', 1),
#  ('있었다.', 1),
#  ('분홍', 1),
#  ('스웨터', 1),
#  ('소매를', 1),
#  ('걷어올린', 1),
#  ('목덜미가', 1),
#  ('마냥', 1),
#  ('희었다.', 1),
#  ('한참', 1),
#  ('세수를', 1),
#  ('하고', 1),
#  ('나더니,', 1),
#  ('이번에는', 1),
#  ('물', 1),
#  ('속을', 1),
#  ('빤히', 1),
#  ('들여다', 1),
#  ('본다.', 1),
#  ('얼굴이라도', 1),
#  ('비추어', 1),
#  ('보는', 1),
#  ('것이리라.', 1),
#  ('갑자기', 1),
#  ('물을', 1),
#  ('움켜', 1)]

# %% [markdown]
# ### 4. 단어별 빈도 세기 및 결과 출력

# %%
# [+] reduceByKey()를 이용하여 단어별 빈도 세기
word_counts = word_pairs.reduceByKey(lambda a,b : a+b)

# %%
# sortBy()를 이용하여 빈도(x[1])를 기준으로 내림차순 정렬
sorted_word_counts = word_counts.sortBy(lambda x: x[1], ascending=False)

# %%
# [+] collect()를 이용하여 정렬된 단어별 빈도를 list 객체로 출력
res = word_counts.collect()

# %%
# 상위 100개의 단어 및 빈도 출력
res[:100]
# Out:
# [('소년은', 14),
#  ('개울가에서', 1),
#  ('소녀를', 2),
#  ('보자', 1),
#  ('곧', 2),
#  ('윤', 1),
#  ('초시네', 1),
#  ('증손녀(曾孫女)딸이라는', 1),
#  ('걸', 2),
#  ('알', 1),
#  ('수', 3),
#  ('있었다.', 14),
#  ('소녀는', 8),
#  ('개울에다', 1),
#  ('손을', 4),
#  ('잠그고', 1),
#  ('물장난을', 3),
#  ('하고', 5),
#  ('있는', 5),
#  ('것이다.', 3),
#  ('서울서는', 1),
#  ('이런', 1),
#  ('개울물을', 1),
#  ('보지', 2),
#  ('못하기나', 1),
#  ('한', 14),
#  ('듯이.', 2),
#  ('벌써', 1),
#  ('며칠째', 2),
#  ('소녀는,', 1),
#  ('학교에서', 1),
#  ('돌아오는', 1),
#  ('길에', 1),
#  ('물장난이었다.', 1),
#  ('그런데,', 3),
#  ('어제까지', 1),
#  ('개울', 1),
#  ('기슭에서', 1),
#  ('하더니,', 1),
#  ('오늘은', 3),
#  ('징검다리', 3),
#  ('한가운데', 2),
#  ('앉아서', 1),
#  ('있다.', 5),
#  ('개울둑에', 2),
#  ('앉아', 6),
#  ('버렸다.', 2),
#  ('소녀가', 20),
#  ('비키기를', 1),
#  ('기다리자는', 1),
#  ('요행', 1),
#  ('지나가는', 2),
#  ('사람이', 2),
#  ('있어,', 1),
#  ('길을', 3),
#  ('비켜', 1),
#  ('주었다.', 2),
#  ('다음', 2),
#  ('날은', 3),
#  ('좀', 3),
#  ('늦게', 2),
#  ('개울가로', 2),
#  ('나왔다.', 2),
#  ('이', 4),
#  ('세수를', 3),
#  ('분홍', 2),
#  ('스웨터', 1),
#  ('소매를', 1),
#  ('걷어올린', 1),
#  ('목덜미가', 2),
#  ('마냥', 1),
#  ('희었다.', 1),
#  ('한참', 1),
#  ('나더니,', 1),
#  ('이번에는', 1),
#  ('물', 6),
#  ('속을', 4),
#  ('빤히', 1),
#  ('들여다', 1),
#  ('본다.', 2),
#  ('얼굴이라도', 1),
#  ('비추어', 1),
#  ('보는', 1),
#  ('것이리라.', 1),
#  ('갑자기', 2),
#  ('물을', 1),
#  ('움켜', 2),
#  ('낸다.', 3),
#  ('고기', 1),
#  ('새끼라도', 1),
#  ('듯.', 1),
#  ('소년이', 9),
#  ('아는지', 1),
#  ('모르는지', 1),
#  ('그냥', 3),
#  ('날쌔게', 1),
#  ('물만', 2),
#  ('그러나,', 5),
#  ('번번이', 1),
#  ('허탕이다.', 1)]
